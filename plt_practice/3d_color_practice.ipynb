# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# prepare some coordinates
x, y, z = np.indices((10, 10, 10))

# %%
tote_1 = (x >= 7) & (y < 8) & (y >= 6) & (z < 2)
tote_2 = (x >= 7) & (y < 2) & (z < 2)
link = abs(x - y) + abs(y - z) + abs(z - x) <= 2

# combine the objects into a single boolean array
# voxelarray = tote_1 | tote_2
voxelarray = link | tote_1

# set the colors of each object
colors = np.empty(voxelarray.shape, dtype=object)
colors[link] = 'violet'
colors[tote_1] = 'lime'

# and plot everything
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(voxelarray, facecolors=colors, edgecolor='k')
# ax.rcparams(figsize=(10,10))

fig = plt.gcf()
fig.set_size_inches(5, 5)
fig.set_dpi(75)
# plt.rcParams["figure.figsize"] = (20,20)
plt.show()

# %%
color_list = ['red', 'orange', 'yellow', 'green', 'cyan', 'blue', 'magenta', 'purple', 'white', 'black', 'gray', 'grey', 'silver', 'pink', 'maroon', 'brown', 'beige', 'tan', 'lime', 'olive', 'turquoise', 'teal', 'indigo', 'violet']
print(color_list)
# Out:
# ['red', 'orange', 'yellow', 'green', 'cyan', 'blue', 'magenta', 'purple', 'white', 'black', 'gray', 'grey', 'silver', 'pink', 'maroon', 'brown', 'beige', 'tan', 'lime', 'olive', 'turquoise', 'teal', 'indigo', 'violet']
